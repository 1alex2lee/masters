# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
test = np.load("input_1.npy")
print(np.shape(test))
plt.imshow(test)
plt.colorbar()
# Out:
# (256, 384)

# %%
test = np.load("input_2.npy")
print(np.shape(test))
plt.imshow(test)
plt.colorbar()
# Out:
# (256, 384)

# %%
blank = np.ones((256,384))
blank[-1,:] = 0
blank[:,-1] = 0
print(np.shape(blank))
plt.imshow(blank)
plt.colorbar()
# Out:
# (256, 384)
