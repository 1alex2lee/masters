# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
test = np.load("imported_die.npy")

# %%
print(np.shape(test))
# Out:
# (256, 384)

# %%
plt.imshow(test)

# %%
plt.imsave("imported_die.png",test)
